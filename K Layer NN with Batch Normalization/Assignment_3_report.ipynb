# %% [markdown]
# # DD2424 deep19 VT19-1 Deep Learning in Data Science - Assignment 3

# %% [markdown]
# <div style="text-align: right"> Sri Datta Budaraju - budaraju@kth.se </div>

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#1.-Submission-Files" data-toc-modified-id="1.-Submission-Files-1">1. Submission Files</a></span></li><li><span><a href="#2.-i)-Gradient-Check" data-toc-modified-id="2.-i)-Gradient-Check-2">2. i) Gradient Check</a></span><ul class="toc-item"><li><span><a href="#3-Layers---w/o-Batch-Norm" data-toc-modified-id="3-Layers---w/o-Batch-Norm-2.1">3 Layers - w/o Batch Norm</a></span></li><li><span><a href="#2-Layers---with-Batch-Norm" data-toc-modified-id="2-Layers---with-Batch-Norm-2.2">2 Layers - with Batch Norm</a></span></li><li><span><a href="#3-Layers---with-Batch-Norm" data-toc-modified-id="3-Layers---with-Batch-Norm-2.3">3 Layers - with Batch Norm</a></span></li></ul></li><li><span><a href="#2.-ii)-Effects-of-Batch-Norm-on-3-layer-network" data-toc-modified-id="2.-ii)-Effects-of-Batch-Norm-on-3-layer-network-3">2. ii) Effects of Batch Norm on 3-layer network</a></span><ul class="toc-item"><li><span><a href="#3-Layers-w/o-BN" data-toc-modified-id="3-Layers-w/o-BN-3.1">3 Layers w/o BN</a></span></li><li><span><a href="#3-Layer-with-BN" data-toc-modified-id="3-Layer-with-BN-3.2">3 Layer with BN</a></span></li></ul></li><li><span><a href="#2.-iii)-Effects-of-Batch-Norm-on-6-layer-network" data-toc-modified-id="2.-iii)-Effects-of-Batch-Norm-on-6-layer-network-4">2. iii) Effects of Batch Norm on 6-layer network</a></span><ul class="toc-item"><li><span><a href="#6-Layers-w/o-BN" data-toc-modified-id="6-Layers-w/o-BN-4.1">6 Layers w/o BN</a></span></li><li><span><a href="#6-Layers-with-BN" data-toc-modified-id="6-Layers-with-BN-4.2">6 Layers with BN</a></span></li></ul></li><li><span><a href="#2.-x)-Effects-of-Batch-Norm-on-9-layer-network" data-toc-modified-id="2.-x)-Effects-of-Batch-Norm-on-9-layer-network-5">2. x) Effects of Batch Norm on 9-layer network</a></span><ul class="toc-item"><li><span><a href="#9-Layers-w/o-BN" data-toc-modified-id="9-Layers-w/o-BN-5.1">9 Layers w/o BN</a></span></li><li><span><a href="#9-Layers-with-BN" data-toc-modified-id="9-Layers-with-BN-5.2">9 Layers with BN</a></span></li></ul></li><li><span><a href="#2.-iv)-Coarse-to-Fine-Random-Search" data-toc-modified-id="2.-iv)-Coarse-to-Fine-Random-Search-6">2. iv) Coarse-to-Fine Random Search</a></span></li></ul></div>

# %% [markdown]
# ## 1. Submission Files
# The assignment has been written in jupyter notebook with Python3.7. The notebook contains all the tasks mentioned in the report in the same order with table to contents pointing to each result of the task. However, I am also submitting the notebook as a python script if it is more convinient to run.
#
# ----

# %% [markdown]
# ## 2. i) Gradient Check
#
# Assuming a good difference between the analytical and numerical gradient is ~1e-06
#
# ### 3 Layers - w/o Batch Norm
# ✔  The gradient for W1 is correct! 2.791079163934215e-07
# ✔  The gradient for b1 is correct! 1.7162123906166537e-07
# ✔  The gradient for W2 is correct! 1.6151792703518448e-07
# ✔  The gradient for b2 is correct! 1.9253426852270733e-07
# ✔  The gradient for W3 is correct! 1.6824461785796703e-07
# ✔  The gradient for b3 is correct! 2.6974931904144094e-07
#
#
# **Observation** - Notice the increase in the difference between the analytic and numerical gradient from W3 to W1. As mentioned in the instructions, it is the due the addition of the approximations of the backprop from the last layer to the first.
#
# ### 2 Layers - with Batch Norm
#
# ✘  The gradient for W1 is Wrong! 0.4041191946276792
# ✔  The gradient for b1 is correct! 5.162835502930473e-11
# ✔  The gradient for gamma1 is correct! 1.6359806423066756e-07
# ✔  The gradient for beta1 is correct! 3.118998036271902e-07
# ✔  The gradient for W2 is correct! 1.5115006204961756e-07
# ✔  The gradient for b2 is correct! 4.185565370775644e-07
# ✔  The gradient for gamma2 is correct! 0.0
# ✔  The gradient for beta2 is correct! 0.0
#
# ### 3 Layers - with Batch Norm
#
# ✘  The gradient for W1 is Wrong! 0.3497729570080334
# ✔  The gradient for b1 is correct! 9.104505742017337e-11
# ✘  The gradient for gamma1 is Wrong! 0.2880781575157003
# ✘  The gradient for beta1 is Wrong! 0.19963532265914638
# ✘  The gradient for W2 is Wrong! 0.4926141418769757
# ✔  The gradient for b2 is correct! 1.9486311806891205e-10
# ✔  The gradient for gamma2 is correct! 1.944510173139876e-07
# ✔  The gradient for beta2 is correct! 2.6882353074992887e-07
# ✔  The gradient for W3 is correct! 1.5954181781528638e-07
# ✔  The gradient for b3 is correct! 2.356172325420203e-07
# ✔  The gradient for gamma3 is correct! 0.0
# ✔  The gradient for beta3 is correct! 0.0
#
# **Observation** - Notice that as mentioned in the assignment instructions, the first layer parameters alone have high difference. However, if these gradients are wrong, that means the network cannot learn from data, but we can observe increase in accuracy with batch norm.
#
# One way to explain the observation is, the batch norm is mainly to help deeper networks learn better. The first layers contribute less to the final prediction than the deeper layers, as batch norm helps the deep layers learn better, the error in the first layer should be less significant than it would be for shallow networks.
#
# ----

# %% [markdown]
# ## 2. ii) Effects of Batch Norm on 3-layer network
#
# ### 3 Layers w/o BN
#
# Network with [50, 50] nodes
#
# ![no_bn_3.png](attachment:no_bn_3.png)
#
# Training Accuracy  0.**59**85111111111111 %
# Training Loss  1.3691902757369419
# Validation Accuracy:  0.5288 %
# Validation Loss:  1.5371887394494483
# Loss on the test dataset : 1.5671833569486695
# Accuracy on the test datset : 0.**51**9
#
# ### 3 Layer with BN
#
# ![bn_3_52.25.png](attachment:bn_3_52.25.png)
# Training Accuracy  0.**63**44222222222222 %
# Training Loss  1.1973220589926148
# Validation Accuracy:  0.5364 %
# Validation Loss:  1.4569441419634712
# Loss on the test dataset : 1.4877549115096742
# Accuracy on the test datset : 0.**52**25
#
# **Observation** - We can see that there is comparitively high increase in the training accuracy but very low increase in the test accuracy. It is also observed that these accuracies vary a lot around **~1%** which implies shuffling the data has considerable impact on the performance as mentioned in the insructions.
#
# ----

# %% [markdown]
# ## 2. iii) Effects of Batch Norm on 6-layer network
#
# ### 6 Layers w/o BN
# Network with [50, 30, 20, 20, 10] nodes
#
# ![no_bn_6.png](attachment:no_bn_6.png)
#
# Training Accuracy  0.**55**8 %
# Training Loss  1.4972485832624918
# Validation Accuracy:  0.498 %
# Validation Loss:  1.6685217932757768
# Loss on the test dataset : 1.6893328628675772
# Accuracy on the test datset : 0.**49**35
#
# ### 6 Layers with BN
#
# ![bn_6.png](attachment:bn_6.png)
#
# Training Accuracy  0.**62**13555555555555 %
# Training Loss  1.2422636978674488
# Validation Accuracy:  0.5316 %
# Validation Loss:  1.4653875273287917
# Loss on the test dataset : 1.4931440459602494
# Accuracy on the test datset : 0.**51**84
#
# **Observation** - As stated above the batch norm should give considerable boost for deeper networks. Though we got only very small increase in 3 layer network, we can see more than **~3%** increase in accuracy.
#
# ----

# %% [markdown]
# ## 2. x) Effects of Batch Norm on 9-layer network
#
# Additional experiment as suggested in the instructions.
# Network with [50, 30, 20, 20, 10, 10, 10, 10] nodes
#
# ### 9 Layers w/o BN
#
# ![no_bn_9.png](attachment:no_bn_9.png)
#
# Training Accuracy  **0.37**85777777777778 %
# Training Loss  1.812810478820503
# Validation Accuracy:  0.353 %
# Validation Loss:  1.9151210071311318
# Loss on the test dataset : 1.9136396980691224
# Accuracy on the test datset : **0.35**02
#
# ### 9 Layers with BN
#
# ![bn_9.png](attachment:bn_9.png)
#
# Training Accuracy  **0.59**81777777777778 %
# Training Loss  1.295552261894014
# Validation Accuracy:  0.5198 %
# Validation Loss:  1.4807593739085978
# Loss on the test dataset : 1.503878730689197
# Accuracy on the test datset : **0.51**41
#
# **Observation** - Now with 9 layer deep network we can see significant performance boost and hence we can saw that the batch norm implementation and the gradients are working as expected. The test accuracy with Batch Norm is 51.41% which is **~15%** more than that of network without batch norm. Also important to know that these accuracies are change a lot from run to run. 51.41% is comparable to shallow 3 layer network without batch norm. So its clear that batch norm helps training deep networks
#
# ---

# %% [markdown]
# ## 2. iv) Coarse-to-Fine Random Search
#
# Coarse Search - 20 lambdas sampled uniformly between 1e-1 to 1e-5 in logscale

# %% [markdown]
# |Lambda|Test Loss|Test Accuracy|
# |---|---|---|
# | 6.194748267364798e-05      | 2.089877730351631       |0.4671  |
# | 1.6650473486464878e-05     | 2.178372683305902       |0.4643  |
# | 2.4228028688537767e-05     | 2.3626717073995533      |0.4619  |
# | **0.004287804093126761**   |**1.5558159615919263**   |**0.5209**|
# | 0.0001263831396222767      | 1.5802820740764758      |0.5102  |
# | 0.00024375449594011585     | 1.781111620842426       |0.4996  |
# | 2.9779670562084457e-05     | 1.871972511008011       |0.4912  |
# | 6.234722503405217e-05      | 1.9713542861978572      |0.4804  |
# | 0.0005094252810437203      | 2.1618535306799216      |0.4828  |
# |**0.01586227974714166**     |**1.5045205169074665**   |**0.525**   |

# %% [markdown]
# |Lambda|Test Loss|Test Accuracy|
# |---|---|---|
# | 6.194748267364798e-05      | 2.089877730351631       |0.4671  |
# | 1.6650473486464878e-05     | 2.178372683305902       |0.4643  |
# | 2.4228028688537767e-05     | 2.3626717073995533      |0.4619  |
# | **0.004287804093126761**   |**1.5558159615919263**   |**0.5209**|
# | 0.0001263831396222767      | 1.5802820740764758      |0.5102  |
# | 0.00024375449594011585     | 1.781111620842426       |0.4996  |
# | 2.9779670562084457e-05     | 1.871972511008011       |0.4912  |
# | 6.234722503405217e-05      | 1.9713542861978572      |0.4804  |
# | 0.0005094252810437203      | 2.1618535306799216      |0.4828  |
# |**0.01586227974714166**     |**1.5045205169074665**   |**0.525**   |
# | 0.08670282923209945        | 1.6768011346706992      |0.4829  |
# | 1.4722714986570704e-05     | 1.4613397107060402      |0.4986  |
# | 0.08653732470068261        | 1.6365989240140173      |0.4811  |
# | 0.0015626755143778113      | 1.5059849443943694      |0.5123  |
# |**0.013686722587540945**    | **1.5068194048068675**  |**0.5175**|
# | 0.019202313839059532       | 1.5199573295056767      |0.5154  |
# | 0.0008080633437037944      | 1.4912668788836354      |0.5138  |
# | 1.797828314827034e-05      | 1.5149800646324618      |0.5031  |
# | 7.237135069692226e-05      | 1.6441079955728997      |0.4931  |
# | 0.06677504149340578        | 1.6532224137653324      |0.4877  |

# %% [markdown]
# ---
#
# Fine Search - 20 samples between 0.01586227974714166, 0.004287804093126761 in log scale
#
# |Lambda|Train Acc|Val Acc| Test Loss| Test Acc|
# |---|---|---|---|---|
# |0.008528010715160766 | 0.6146666666666667 | 0.5376 |  1.480800275703781 | 0.5191|
# |0.007459492824676242 | 0.6295777777777778 | 0.5372 |  1.471055223648025 | 0.5259|
# |0.007904168469325722 | 0.6306666666666667 | 0.5438 |  1.4577965163736903 | 0.5266|
# |0.014074351302603766 | 0.6042222222222222 | 0.5326 |  1.4700821098132866 | 0.5225|
# |0.01253101535313128 | 0.6079111111111111 | 0.5312 |  1.4600159163523072 | 0.5255|
# |0.008888203234485758 | 0.6255555555555555 | 0.5414 |  1.4608927943873264 | 0.5255|
# |0.004395733417085532 | 0.6595333333333333 | 0.5428 |  1.4810317355211091 | **0.5301**|
# |0.004711164742135594 | 0.6595111111111112 | 0.5392 |  1.4833420601294303 | 0.5267|
# |0.007472360421957255 | 0.6369777777777778 | 0.5464 |  1.4634252178998692 | 0.5275|
# |0.011331244020057108 | 0.6193777777777778 | 0.5438 |  1.4611877010953433 | 0.5255|
# |0.004366243703126039 | 0.6609111111111111 | 0.5462 |  1.4731673910733538 | 0.5271|
# |0.014249535871635655 | 0.6096444444444444 | 0.5356 |  1.4737491442494888 | 0.5243|
# |0.011965118389623117 | 0.6137555555555556 | 0.5366 |  1.4645327943081738 | 0.5261|
# |0.00758860864771491 | 0.6361777777777777 | 0.537 |  1.4590896197894836 | **0.5277**|
# |0.011281361723500806 | 0.6152444444444445 | 0.536 |  1.4622965581735548 | 0.5218|
# |0.006422007481158785 | 0.6433777777777778 | 0.537 |  1.4636167739383916 | 0.5244|
# |0.009865405061217518 | 0.6235777777777778 | 0.537 |  1.4641647750066964 | 0.5212|
# |0.004902429047423366 | 0.6562666666666667 | 0.5364 |  1.4791538289825823 | 0.5249|
# |0.006756949535014469 | 0.6403111111111112 | 0.5318 |  1.4683461054608855 | 0.5264|
# |0.006446956197735122 | 0.646 | 0.5352 |  1.4732717376150017 | **0.5281**|
